# %%
from pathlib import Path
import iris
import xarray as xr

# %%
BC_ARCHIVE_DIR=Path("/g/data/v45/lbc_archive/era5land")
EC_IC_LBC_DIR=Path("/g/data/gb02/pag548/aus2200/aus2200_era5_smc")
ANCIL_PATH=Path("/scratch/gb02/pag548/cylc-run/u-cp145/share/data/ancils/aus2200/")

# %%
grib = iris.load(EC_IC_LBC_DIR / 'ec_grib_201606030000.t+000')

# %%
da = xr.DataArray.from_iris(grib[0])

# %%
da
# Out:
# <xarray.DataArray 'grib_skin_temperature' (latitude: 180, longitude: 217)> Size: 312kB
# dask.array<filled, shape=(180, 217), dtype=float64, chunksize=(180, 217), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude            (latitude) float64 1kB -5.5 -5.75 -6.0 ... -50.0 -50.25
#   * longitude           (longitude) float64 2kB 106.2 106.5 ... 160.0 160.2
#     forecast_period     timedelta64[ns] 8B ...
#     originating_centre  <U50 200B ...
#     time                datetime64[ns] 8B ...
# Attributes:
#     long_name:  grib_skin_temperature
#     units:      K

# %%
da.plot()

# %%
da.longitude.max()
# Out:
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(160.25)
# Coordinates:
#     forecast_period     timedelta64[ns] 8B ...
#     originating_centre  <U50 200B ...
#     time                datetime64[ns] 8B ...

# %%
era5_mask = xr.DataArray.from_iris(iris.load(ANCIL_PATH / 'era5/qrparm.mask')[0])

# %%
era5_mask.longitude.max()
# Out:
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(159.47520447)

# %%
d0198_mask = xr.DataArray.from_iris(iris.load(ANCIL_PATH / 'd0198/qrparm.mask')[0])

# %%
d0198_mask.longitude.max()
# Out:
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(158.98019409)
